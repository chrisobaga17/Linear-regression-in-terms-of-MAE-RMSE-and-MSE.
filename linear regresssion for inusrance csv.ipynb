# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
insurance_data = pd.read_csv("insurance.csv")

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'bmi'}>],
#        [<AxesSubplot:title={'center':'children'}>,
#         <AxesSubplot:title={'center':'charges'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

plt.scatter(X_test['bmi'], y_test, color='red')
plt.plot(X_test['bmi'], y_pred, color='blue')
plt.title('BMI vs Charges')
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.show()

# %%
plt.scatter(X_test['bmi'], y_test-y_pred, color='green')
plt.hlines(y=0, xmin=min(X_test['bmi']), xmax=max(X_test['bmi']), color='red', linestyle='--')
plt.title('Residuals plot')
plt.xlabel('BMI')
plt.ylabel('Residuals')
plt.show()

# %%
X = insurance_data.drop("charges", axis=1)
y = insurance_data["charges"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train = pd.get_dummies(X_train, columns=["sex", "smoker", "region"], drop_first=True)
X_test = pd.get_dummies(X_test, columns=["sex", "smoker", "region"], drop_first=True)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
y_pred = reg.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Absolute Error: 3933.272649405235
# Mean Squared Error: 31827950.229523838
# R^2 Score: 0.7999876970680433
